# %% [markdown]
# # Data Processing and Analysis
#
# Data Processing is the most important and most time consuming component of the overall lifecycle of any Machine Learning project.
#
# In this notebook, we will analyze a dummy dataset to understand different issues we face with real world datasets and steps to handle the same.

# %% [markdown]
# ## Import

# %%
# import required libraries
import datetime
import random
from random import randrange

import numpy as np
import pandas as pd
from IPython.display import display
from sklearn import preprocessing

pd.options.mode.chained_assignment = None

# %% [markdown]
# ## Dataset Utilities

# %%
def _random_date(start,date_count):
    """This function generates a random date based on params
    Args:
        start (date object): the base date
        date_count (int): number of dates to be generated
    Returns:
        list of random dates

    """
    current = start
    while date_count > 0:
        curr = current + datetime.timedelta(days=randrange(42))
        yield curr
        date_count-=1

# %%
def generate_sample_data(row_count=100):
    """This function generates a random transaction dataset
    Args:
        row_count (int): number of rows for the dataframe
    Returns:
        a pandas dataframe

    """

    # sentinels
    startDate = datetime.datetime(2016, 1, 1, 13)
    serial_number_sentinel = 1000
    user_id_sentinel = 5001
    product_id_sentinel = 101
    price_sentinel = 2000

    # base list of attributes
    data_dict = {
        'Serial No':
        np.arange(row_count) + serial_number_sentinel,
        'Date':
        np.random.permutation(
            pd.to_datetime([
                x.strftime("%d-%m-%Y")
                for x in _random_date(startDate, row_count)
            ]).date),
        'User ID':
        np.random.permutation(
            np.random.randint(0, row_count, size=int(row_count / 10)) +
            user_id_sentinel).tolist() * 10,
        'Product ID':
        np.random.permutation(
            np.random.randint(0, row_count, size=int(row_count / 10)) +
            product_id_sentinel).tolist() * 10,
        'Quantity Purchased':
        np.random.permutation(np.random.randint(1, 42, size=row_count)),
        'Price':
        np.round(
            np.abs(np.random.randn(row_count) + 1) * price_sentinel,
            decimals=2),
        'User Type':
        np.random.permutation(
            [chr(random.randrange(97, 97 + 3 + 1)) for i in range(row_count)])
    }

    # introduce missing values
    for index in range(int(np.sqrt(row_count))):
        data_dict['Price'][np.argmax(
            data_dict['Price'] == random.choice(data_dict['Price']))] = np.nan
        data_dict['User Type'][np.argmax(
            data_dict['User Type'] == random.choice(
                data_dict['User Type']))] = np.nan
        data_dict['Date'][np.argmax(
            data_dict['Date'] == random.choice(data_dict['Date']))] = np.nan
        data_dict['Product ID'][np.argmax(data_dict['Product ID'] == random.
                                          choice(data_dict['Product ID']))] = 0
        data_dict['Serial No'][np.argmax(data_dict['Serial No'] == random.
                                         choice(data_dict['Serial No']))] = -1
        data_dict['User ID'][np.argmax(data_dict['User ID'] == random.choice(
            data_dict['User ID']))] = -101

    # create data frame
    df = pd.DataFrame(data_dict)

    return df

# %% [markdown]
# ## Generate Dataset

# %%
## Generate a dataset with 1000 rows
df = generate_sample_data(row_count=___)
df.shape
# Out:
# (1000, 7)

# %% [markdown]
# ### Analyze generated Dataset

# %%
df.head()
# Out:
#    Serial No        Date  User ID  Product ID  Quantity Purchased    Price  \
# 0       1000  2016-01-22     -101           0                  39  2571.49
# 1       1001         NaN     5683         877                   3  2466.93
# 2       1002         NaN     5418         853                  32  2323.22
# 3       1003  2016-05-01     5730         358                  37  2812.33
# 4       1004  2016-01-20     5002         729                  30  4634.88
#
#   User Type
# 0         n
# 1         n
# 2         n
# 3         n
# 4         n

# %%
def describe_dataframe(df=pd.DataFrame()):
    """This function generates descriptive stats of a dataframe
    Args:
        df (dataframe): the dataframe to be analyzed
    Returns:
        None

    """
    print("\n\n")
    print("*"*30)
    print("About the Data")
    print("*"*30)
    
    print("Number of rows::",df.shape[0])
    print("Number of columns::",df.shape[__])
    print("\n")
    
    print("Column Names::",df.columns.values.tolist())
    print("\n")
    
    print("Column Data Types::\n",df.dtypes)
    print("\n")
    
    print("Columns with Missing Values::",df.columns[df.isnull().any()].tolist())
    print("\n")
    
    print("Number of rows with Missing Values::",len(pd.isnull(df).any(1).nonzero()[0].tolist()))
    print("\n")
    
    print("Sample Indices with missing data::",pd.isnull(df).any(1).nonzero()[0].tolist()[0:5])
    print("\n")
    
    print("General Stats::")
    print(df.info())
    print("\n")
    
    print("Summary Stats::")
    print(df.describe())
    print("\n")
    
    print("Dataframe Sample Rows::")
    display(df.head(5))

# %%
describe_dataframe(df)
# Out:
# ******************************
# About the Data
# ******************************
# Number of rows:: 1000
# Number of columns:: 7
#
#
# Column Names:: ['Serial No', 'Date', 'User ID', 'Product ID', 'Quantity Purchased', 'Price', 'User Type']
#
#
# Column Data Types::
#  Serial No               int64
# Date                   object
# User ID                 int64
# Product ID              int64
# Quantity Purchased      int64
# Price                 float64
# User Type              object
# dtype: object
#
#
# Columns with Missing Values:: ['Date', 'Price']
#
#
# Number of rows with Missing Values:: 60
#
#
# Sample Indices with missing data:: [1, 2, 6, 7, 13]
#
#
# General Stats::
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# Serial No             1000 non-null int64
# Date                  969 non-null object
# User ID               1000 non-null int64
# Product ID            1000 non-null int64
# Quantity Purchased    1000 non-null int64
# Price                 969 non-null float64
# User Type             1000 non-null object
# dtypes: float64(1), int64(4), object(2)
# memory usage: 54.8+ KB
# None
#
#
# Summary Stats::
#          Serial No      User ID  Product ID  Quantity Purchased        Price
# count  1000.000000  1000.000000  1000.00000         1000.000000   969.000000
# mean   1449.573000  5505.369000   594.49200           21.281000  2355.749639
# std     384.925791   337.835371   292.82299           11.699526  1660.892544
# min      -1.000000  -101.000000     0.00000            1.000000     6.000000
# 25%    1221.750000  5237.000000   358.00000           11.000000  1015.500000
# 50%    1477.500000  5486.000000   624.50000           22.000000  2102.790000
# 75%    1740.250000  5747.750000   837.50000           31.000000  3416.950000
# max    1999.000000  5996.000000  1084.00000           41.000000  8728.400000
#
#
# Dataframe Sample Rows::
#    Serial No        Date  User ID  Product ID  Quantity Purchased    Price  \
# 0       1000  2016-01-22     -101           0                  39  2571.49
# 1       1001         NaN     5683         877                   3  2466.93
# 2       1002         NaN     5418         853                  32  2323.22
# 3       1003  2016-05-01     5730         358                  37  2812.33
# 4       1004  2016-01-20     5002         729                  30  4634.88
#
#   User Type
# 0         n
# 1         n
# 2         n
# 3         n
# 4         n

# %% [markdown]
# ## Standardize Columns

# %%
# list all columns
print("Dataframe columns:\n{}".format(df.___.___()))
# Out:
# Dataframe columns:
# ['Serial No', 'Date', 'User ID', 'Product ID', 'Quantity Purchased', 'Price', 'User Type']

# %% [markdown]
# ### Utility to Standardize Columns

# %%
def cleanup_column_names(df,rename_dict={},do_inplace=True):
    """This function renames columns of a pandas dataframe
       It converts column names to snake case if rename_dict is not passed. 
    Args:
        rename_dict (dict): keys represent old column names and values point to 
                            newer ones
        do_inplace (bool): flag to update existing dataframe or return a new one
    Returns:
        pandas dataframe if do_inplace is set to False, None otherwise

    """
    if not rename_dict:
        return df.rename(columns={col: col.___().replace(' ','_') 
                    for col in df.columns.values.tolist()}, 
                  inplace=_____)
    else:
        return df.rename(columns=rename_dict,inplace=do_inplace)

# %%
cleanup_column_names(df)

# %%
# Updated column names
print("Dataframe columns:\n{}".format(df.columns.tolist()))
# Out:
# Dataframe columns:
# ['serial_no', 'date', 'user_id', 'product_id', 'quantity_purchased', 'price', 'user_type']

# %% [markdown]
# ## Basic Manipulation

# %% [markdown]
# ### Sort basis specific attributes

# %%
# Ascending for Serial No and Descending for Price
display(df.sort_values(['serial_no', 'price'], 
                         ascending=[True, ___]).head())
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 151         -1  2016-11-01     5979         220                  20  4897.51
# 406         -1  2016-01-26     5467         873                  10  4893.92
# 519         -1  2016-01-20     5461         850                  12  4702.06
# 956         -1  2016-01-21     5996        1074                   2  4664.97
# 595         -1  2016-01-30     5308         222                  37  4590.35
#
#     user_type
# 151         c
# 406         d
# 519         c
# 956         d
# 595         c

# %% [markdown]
# ### Reorder columns

# %%
display(df[['serial_no','date','user_id','user_type',
              'product_id','quantity_purchased','price']].head())
# Out:
#    serial_no        date  user_id user_type  product_id  quantity_purchased  \
# 0       1000  2016-01-22     -101         n           0                  39
# 1       1001         NaN     5683         n         877                   3
# 2       1002         NaN     5418         n         853                  32
# 3       1003  2016-05-01     5730         n         358                  37
# 4       1004  2016-01-20     5002         n         729                  30
#
#      price
# 0  2571.49
# 1  2466.93
# 2  2323.22
# 3  2812.33
# 4  4634.88

# %% [markdown]
# ### Select Attributes

# %%
# Using Column Index
# print 10 values from column at index 3
print(df.iloc[:,3].values[0:10])
# Out:
# [  0 877 853 358 729 434 873 173 742 142]

# %%
# Using Column Name
# print 10 values of quantity purchased
print(df.quantity_purchased.values[0:10])
# Out:
# [39  3 32 37 30 31 27 36  5 34]

# %%
# Using Datatype
# print 10 values of columns with data type float
print(df.select_dtypes(include=['float64']).values[:10,0])
# Out:
# [2571.49 2466.93 2323.22 2812.33 4634.88 2659.72 1282.97 1683.48 3242.85
#   175.81]

# %% [markdown]
# ### Select Rows

# %%
# Using Row Index
display(df.iloc[[10,501,20]])
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 10        1010  2016-01-24     5073         808                  19  2347.45
# 501       1501  2016-07-01     5683         877                   2   545.09
# 20        1020  2016-01-30     5316         462                  29   157.65
#
#     user_type
# 10          n
# 501         b
# 20          n

# %%
# Exclude specific rows
display(df.drop([0,24,51], axis=0).head())
# Out:
#    serial_no        date  user_id  product_id  quantity_purchased    price  \
# 1       1001         NaN     5683         877                   3  2466.93
# 2       1002         NaN     5418         853                  32  2323.22
# 3       1003  2016-05-01     5730         358                  37  2812.33
# 4       1004  2016-01-20     5002         729                  30  4634.88
# 5       1005  2016-11-02     5173         434                  31  2659.72
#
#   user_type
# 1         n
# 2         n
# 3         n
# 4         n
# 5         n

# %%
# Conditional Filtering
# Quantity_Purchased greater than 25
display(df[df.quantity_purchased __ 25].head())
# Out:
#    serial_no        date  user_id  product_id  quantity_purchased    price  \
# 0       1000  2016-01-22     -101           0                  39  2571.49
# 2       1002         NaN     5418         853                  32  2323.22
# 3       1003  2016-05-01     5730         358                  37  2812.33
# 4       1004  2016-01-20     5002         729                  30  4634.88
# 5       1005  2016-11-02     5173         434                  31  2659.72
#
#   user_type
# 0         n
# 2         n
# 3         n
# 4         n
# 5         n

# %%
# Offset from Top
display(df[100:].head())
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 100       1100  2016-01-16     5700         388                  11  5612.74
# 101       1101  2016-01-21     5683         877                  10  5703.08
# 102       1102         NaN     5418         853                  37  4826.85
# 103       1103  2016-01-27     5730         358                   1  2936.60
# 104       1104  2016-03-01     5002         729                   2  3383.50
#
#     user_type
# 100         c
# 101         b
# 102         d
# 103         a
# 104         a

# %%
# Offset from Bottom
display(df[-10:].head())
# Out:
#      serial_no        date  user_id  product_id  quantity_purchased    price  \
# 990       1990  2016-08-02     5371         633                   4  3151.37
# 991       1991  2016-11-02     5636         994                  27  3614.81
# 992       1992  2016-01-26     5508         562                   8  1334.92
# 993       1993  2016-10-02     5898         904                  26  5036.20
# 994       1994  2016-10-02     5442        1016                  23  5191.03
#
#     user_type
# 990         a
# 991         b
# 992         c
# 993         c
# 994         c

# %% [markdown]
# ### Type Casting

# %%
# Existing Datatypes
df.dtypes
# Out:
# serial_no               int64
# date                   object
# user_id                 int64
# product_id              int64
# quantity_purchased      int64
# price                 float64
# user_type              object
# dtype: object

# %%
# Set Datatime as dtype for date column
df['date'] = pd.to_datetime(df.date)
print(df.dtypes)
# Out:
# serial_no                      int64
# date                  datetime64[ns]
# user_id                        int64
# product_id                     int64
# quantity_purchased             int64
# price                        float64
# user_type                     object
# dtype: object

# %% [markdown]
# ### Map/Apply Functionality

# %%
def expand_user_type(u_type):
    """This function maps user types to user classes
    Args:
        u_type (str): user type value
    Returns:
        (str) user_class value

    """
    if u_type in ['a','b']:
        return 'new'
    elif u_type == 'c':
        return 'existing'
    elif u_type == 'd':
        return 'loyal_existing'
    else:
        return 'error'

# %%
# Map User Type to User Class
df['user_class'] = df['user_type'].map(____)
display(df.tail())
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 995         -1 2016-08-01     5308         222                  23   890.11
# 996       1996 2016-01-28     5468         376                   5  2660.33
# 997       1997 2016-10-01     5632        1005                   9  3380.72
# 998       1998 2016-03-02     5005         220                  11  2629.37
# 999       1999 2016-07-01     5487         420                   4  1368.66
#
#     user_type      user_class
# 995         c        existing
# 996         c        existing
# 997         b             new
# 998         c        existing
# 999         d  loyal_existing

# %%
# Apply: Using apply to get attribute ranges
display(df.select_dtypes(include=[np.number]).apply(lambda x: 
                                                        x.max()- x.____()))
# Out:
# serial_no             2000.0
# user_id               6097.0
# product_id            1084.0
# quantity_purchased      40.0
# price                 8722.4
# dtype: float64

# %%
# Apply-Map: Extract Week from Date
df['purchase_week'] = df[['date']].applymap(lambda dt:dt.week 
                                                if not pd.isnull(dt.week) 
                                                else 0)

# %%
display(df.head())
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000 2016-01-22     -101           0                  39  2571.49
# 1       1001        NaT     5683         877                   3  2466.93
# 2       1002        NaT     5418         853                  32  2323.22
# 3       1003 2016-05-01     5730         358                  37  2812.33
# 4       1004 2016-01-20     5002         729                  30  4634.88
#
#   user_type user_class  purchase_week
# 0         n      error              3
# 1         n      error              0
# 2         n      error              0
# 3         n      error             17
# 4         n      error              3

# %% [markdown]
# ## Handle Missing Values

# %%
# Drop Rows with Missing Dates
df_dropped = df.dropna(subset=['date'])
display(df_dropped.head())
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000 2016-01-22     -101           0                  39  2571.49
# 3       1003 2016-05-01     5730         358                  37  2812.33
# 4       1004 2016-01-20     5002         729                  30  4634.88
# 5       1005 2016-11-02     5173         434                  31  2659.72
# 8       1008 2016-01-27     5189         742                   5  3242.85
#
#   user_type user_class  purchase_week
# 0         n      error              3
# 3         n      error             17
# 4         n      error              3
# 5         n      error             44
# 8         n      error              4

# %%
# Filling missing price with mean price
df_dropped['price'].fillna(value=np.round(df.price.mean(),decimals=2),
                                inplace=True)

# %%
# Fill missing user types using values from previous row
df_dropped['user_type'].fillna(method='ffill',inplace=True)

# %% [markdown]
# ## Handle Duplicates

# %%
# sample duplicates. Identify for serial_no
display(df_dropped[df_dropped.duplicated(subset=[____])].head())
print("Shape of df={}".format(df_dropped.shape))
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 151         -1 2016-11-01     5979         220                  20  4897.51
# 287         -1 2016-01-21     5245         808                  11  1280.13
# 291         -1 2016-01-18     5636         994                  24   195.15
# 393         -1 2016-01-28     5898         904                  23  4083.97
# 396         -1 2016-01-15     5468         376                  28  1945.53
#
#     user_type user_class  purchase_week
# 151         c   existing             44
# 287         a        new              3
# 291         b        new              3
# 393         b        new              4
# 396         b        new              2
# Shape of df=(969, 9)

# %%
# Drop Duplicates
df_dropped.drop_duplicates(subset=['serial_no'],inplace=True)
display(df_dropped.head())
print("Shape of df={}".format(df_dropped.shape))
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000 2016-01-22     -101           0                  39  2571.49
# 3       1003 2016-05-01     5730         358                  37  2812.33
# 4       1004 2016-01-20     5002         729                  30  4634.88
# 5       1005 2016-11-02     5173         434                  31  2659.72
# 8       1008 2016-01-27     5189         742                   5  3242.85
#
#   user_type user_class  purchase_week
# 0         n      error              3
# 3         n      error             17
# 4         n      error              3
# 5         n      error             44
# 8         n      error              4
# Shape of df=(940, 9)

# %%
# Remove rows which have less than 3 attributes with non-missing data
display(df.dropna(thresh=___).head())
print("Shape of df={}".format(df.dropna(thresh=____).shape))
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000 2016-01-22     -101           0                  39  2571.49
# 1       1001        NaT     5683         877                   3  2466.93
# 2       1002        NaT     5418         853                  32  2323.22
# 3       1003 2016-05-01     5730         358                  37  2812.33
# 4       1004 2016-01-20     5002         729                  30  4634.88
#
#   user_type user_class  purchase_week
# 0         n      error              3
# 1         n      error              0
# 2         n      error              0
# 3         n      error             17
# 4         n      error              3
# Shape of df=(1000, 9)

# %% [markdown]
# ## Handle Categoricals

# %% [markdown]
# ### One Hot Encoding

# %%
display(pd.get_dummies(df,columns=['user_type']).head())
# Out:
#    serial_no       date  user_id  product_id  quantity_purchased    price  \
# 0       1000 2016-01-22     -101           0                  39  2571.49
# 1       1001        NaT     5683         877                   3  2466.93
# 2       1002        NaT     5418         853                  32  2323.22
# 3       1003 2016-05-01     5730         358                  37  2812.33
# 4       1004 2016-01-20     5002         729                  30  4634.88
#
#   user_class  purchase_week  user_type_a  user_type_b  user_type_c  \
# 0      error              3            0            0            0
# 1      error              0            0            0            0
# 2      error              0            0            0            0
# 3      error             17            0            0            0
# 4      error              3            0            0            0
#
#    user_type_d  user_type_n
# 0            0            1
# 1            0            1
# 2            0            1
# 3            0            1
# 4            0            1

# %% [markdown]
# ### Label Encoding

# %%
type_map = {'a': 0, 'b': 1, 'c': 2, 'd': 3, np.NAN: -1}
df['encoded_user_type'] = df.user_type.map(____)
display((df.tail()))
# Out:
#      serial_no       date  user_id  product_id  quantity_purchased    price  \
# 995         -1 2016-08-01     5308         222                  23   890.11
# 996       1996 2016-01-28     5468         376                   5  2660.33
# 997       1997 2016-10-01     5632        1005                   9  3380.72
# 998       1998 2016-03-02     5005         220                  11  2629.37
# 999       1999 2016-07-01     5487         420                   4  1368.66
#
#     user_type      user_class  purchase_week  encoded_user_type
# 995         c        existing             31                2.0
# 996         c        existing              4                2.0
# 997         b             new             39                1.0
# 998         c        existing              9                2.0
# 999         d  loyal_existing             26                3.0

# %% [markdown]
# ## Handle Numerical Attributes

# %% [markdown]
# ### Min-Max Scalar

# %%
df_normalized = df.dropna().copy()
min_max_scaler = preprocessing.______()
np_scaled = min_max_scaler.fit_transform(df_normalized['price'].values.reshape(-1,1))
df_normalized['price'] = np_scaled.reshape(-1,1)

# %%
display(df_normalized.head())
# Out:
#     serial_no       date  user_id  product_id  quantity_purchased     price  \
# 22       1022 2016-01-01     5676        1067                  19  0.214495
# 28       1028 2016-04-01     5973         104                  12  0.136061
# 30       1030 2016-01-25     5207         286                  23  0.257740
# 31       1031 2016-08-01     5688         583                  31  0.232022
# 33       1033 2016-06-02     5139         947                   6  0.274444
#
#    user_type      user_class  purchase_week  encoded_user_type
# 22         d  loyal_existing             53                3.0
# 28         d  loyal_existing             13                3.0
# 30         d  loyal_existing              4                3.0
# 31         d  loyal_existing             31                3.0
# 33         a             new             22                0.0

# %% [markdown]
# ### Robust Scalar

# %%
df_normalized = df.dropna().copy()
robust_scaler = preprocessing.RobustScaler()
rs_scaled = robust_scaler._______(df_normalized['quantity_purchased'].values.reshape(-1,1))
df_normalized['quantity_purchased'] = rs_scaled.reshape(-1,1)

# %%
display(df_normalized.head())
# Out:
#     serial_no       date  user_id  product_id  quantity_purchased    price  \
# 22       1022 2016-01-01     5676        1067           -0.142857  1879.91
# 28       1028 2016-04-01     5973         104           -0.476190  1196.08
# 30       1030 2016-01-25     5207         286            0.047619  2256.95
# 31       1031 2016-08-01     5688         583            0.428571  2032.72
# 33       1033 2016-06-02     5139         947           -0.761905  2402.58
#
#    user_type      user_class  purchase_week  encoded_user_type
# 22         d  loyal_existing             53                3.0
# 28         d  loyal_existing             13                3.0
# 30         d  loyal_existing              4                3.0
# 31         d  loyal_existing             31                3.0
# 33         a             new             22                0.0

# %% [markdown]
# ## Group-By

# %%
# Group By certain attributes user_class and get sum of quantity_purchased
print(df.groupby(['user_class'])['quantity_purchased'].____())
# Out:
# user_class
# error               689
# existing           5575
# loyal_existing     4670
# new               10347
# Name: quantity_purchased, dtype: int64

# %%
# Aggregate Functions. Sum, Mean and Non Zero Row Count
display(
    df.groupby(['user_class'])['quantity_purchased'].agg(
        [np.____, np.____, np.count_nonzero]))
# Out:
#                   sum       mean  count_nonzero
# user_class
# error             689  22.225806             31
# existing         5575  22.662602            246
# loyal_existing   4670  20.304348            230
# new             10347  20.987830            493

# %%
# Aggregate Functions specific to columns
display(df.groupby(['user_class','user_type']).agg({'price':np.mean,
                                                        'quantity_purchased':np.max}))
# Out:
#                                 price  quantity_purchased
# user_class     user_type
# error          n          2644.041290                  39
# existing       c          2374.785679                  41
# loyal_existing d          2450.062273                  41
# new            a          2107.919437                  41
#                b          2449.754549                  41

# %%
# Multiple Aggregate Functions
display(
    df.groupby(['user_class', 'user_type']).agg({
        'price': {
            'total_price': np.sum,
            'mean_price': np.mean,
            'variance_price': np.std,
            'count': np.count_nonzero
        },
        'quantity_purchased': np.sum
    }))
# Out:
# /Users/rbali2/anaconda/lib/python3.6/site-packages/pandas/core/groupby/groupby.py:4656: FutureWarning: using a dict with renaming is deprecated and will be removed in a future version
#   return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#                                price                                     \
#                          total_price   mean_price variance_price  count
# user_class     user_type
# error          n            81965.28  2644.041290    1945.440890   31.0
# existing       c           577072.92  2374.785679    1628.365448  246.0
# loyal_existing d           539013.70  2450.062273    1622.086894  230.0
# new            a           486929.39  2107.919437    1549.298323  241.0
#                b           597740.11  2449.754549    1775.230970  252.0
#
#                          quantity_purchased
#                                         sum
# user_class     user_type
# error          n                        689
# existing       c                       5575
# loyal_existing d                       4670
# new            a                       5208
#                b                       5139

# %% [markdown]
# ## Pivot Tables

# %%
display(df.pivot_table(index='date', columns='user_type', 
                         values='price',aggfunc=np.mean))
# Out:
# user_type             a            b            c            d            n
# date
# 2016-01-01  2252.256667  3039.420000  4030.830000  2609.781667  2096.495000
# 2016-01-02  2348.065000  2234.445000  3417.777500  2462.582500   915.280000
# 2016-01-13  1112.392500  3181.868750  1750.672500  2505.297778          NaN
# 2016-01-14  3103.557500  3106.012000  3687.740000  2936.520000          NaN
# 2016-01-15  1915.987143  1942.046000  1614.273333  3527.080000          NaN
# 2016-01-16  2910.938889  4032.250000  3273.530000  1868.254000          NaN
# 2016-01-17  2207.140000  1882.300000   526.880000   841.180000   175.810000
# 2016-01-18  1707.212857  2471.696667  1531.380000  2284.608333          NaN
# 2016-01-19  2541.122000  1534.025000  2259.712000  1358.688333          NaN
# 2016-01-20  2151.460000  1732.940000  2497.088333  2726.943333  2714.993333
# 2016-01-21  2115.110000  3663.145000  2470.912500  2481.138750          NaN
# 2016-01-22  2211.507500  2837.664000  3714.393333  3388.220000  2571.490000
# 2016-01-23  1322.030000  1412.018000  4308.540000  2254.631667          NaN
# 2016-01-24  2506.670000  2655.571667  2326.858333   184.560000  2347.450000
# 2016-01-25  1455.206250  1920.791429  1908.892000  2505.961250          NaN
# 2016-01-26  2242.515455  3012.988333   964.197500  3184.628889  1286.460000
# 2016-01-27  3013.445000  1210.220000  2977.250000  1955.570000  3242.850000
# 2016-01-28  2380.026667  2222.108000  1277.593333  2606.742857          NaN
# 2016-01-29  1732.398571  3605.835000  2073.446000  3041.037500          NaN
# 2016-01-30  2725.566250  4656.022500  2433.810000  3040.126667  3335.335000
# 2016-01-31  2551.660000  2084.902500  1370.070000  2516.762000          NaN
# 2016-02-01  1191.705000  1328.948182  1907.856667  3062.020000          NaN
# 2016-02-02  1987.958182  2749.967500  2346.422857  1350.286000          NaN
# 2016-03-01  2644.850000  2201.786667  2533.101000  3099.365000          NaN
# 2016-03-02  1964.670000  2726.493333  1573.352222  2251.374000          NaN
# 2016-04-01  2026.241667  3311.806667  2504.075000  2424.080000  4943.340000
# 2016-04-02  2321.867500  3051.240000  2606.406667  3248.670000          NaN
# 2016-05-01  1861.656000  1823.312857  2378.535000  3088.054286  2812.330000
# 2016-05-02  1186.775000  3653.172500  2218.952000  2620.040000          NaN
# 2016-06-01   493.900000  1655.632000  2337.967500  2441.944000          NaN
# 2016-06-02  2245.593000  1451.770000  2946.758333  3214.630000  1373.640000
# 2016-07-01  1973.087143  1789.703333  1920.562000  1777.553333          NaN
# 2016-07-02  1784.268000  1540.624286  1451.285000  1094.686667  1384.270000
# 2016-08-01   373.415000  2630.821429  2639.093333  2011.928750  2286.910000
# 2016-08-02  1389.437000  2193.204000  4031.000000  1977.340000  5914.240000
# 2016-09-01  2910.452500  2608.271000  1668.038000  3270.596667          NaN
# 2016-09-02  2093.211429  3280.356000  3166.432500   376.250000          NaN
# 2016-10-01  3500.455000  2077.875000  2320.556000  1556.680000          NaN
# 2016-10-02  1408.106000  1706.730000  3786.024545  1769.217500          NaN
# 2016-11-01  2564.248000  3316.795000  1979.638000  2230.575714  8191.470000
# 2016-11-02  1712.674000  2848.010000  1963.094000  2461.160000  2659.720000
# 2016-12-01   740.260000  1814.541250  3450.600000  2154.747500          NaN

# %% [markdown]
# ## Stacking

# %%
print(df.stack())
# Out:
# 0    serial_no                            1000
#      date                  2016-01-22 00:00:00
#      user_id                              -101
#      product_id                              0
#      quantity_purchased                     39
#      price                             2571.49
#      user_type                               n
#      user_class                          error
#      purchase_week                           3
# 1    serial_no                            1001
#      user_id                              5683
#      product_id                            877
#      quantity_purchased                      3
#      price                             2466.93
#      user_type                               n
#      user_class                          error
#      purchase_week                           0
# 2    serial_no                            1002
#      user_id                              5418
#      product_id                            853
#      quantity_purchased                     32
#      price                             2323.22
#      user_type                               n
#      user_class                          error
#      purchase_week                           0
# 3    serial_no                            1003
#      date                  2016-05-01 00:00:00
#      user_id                              5730
#      product_id                            358
#      quantity_purchased                     37
#                                   ...
# 997  serial_no                            1997
#      date                  2016-10-01 00:00:00
#      user_id                              5632
#      product_id                           1005
#      quantity_purchased                      9
#      price                             3380.72
#      user_type                               b
#      user_class                            new
#      purchase_week                          39
#      encoded_user_type                       1
# 998  serial_no                            1998
#      date                  2016-03-02 00:00:00
#      user_id                              5005
#      product_id                            220
#      quantity_purchased                     11
#      price                             2629.37
#      user_type                               c
#      user_class                       existing
#      purchase_week                           9
#      encoded_user_type                       2
# 999  serial_no                            1999
#      date                  2016-07-01 00:00:00
#      user_id                              5487
#      product_id                            420
#      quantity_purchased                      4
#      price                             1368.66
#      user_type                               d
#      user_class                 loyal_existing
#      purchase_week                          26
#      encoded_user_type                       3
# Length: 9907, dtype: object
